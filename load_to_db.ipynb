# %% [markdown]
# <a href="https://colab.research.google.com/github/mjahanzaib99/ETL_Pipeline/blob/main/load_to_db.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Upsertion In MangoDB

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 21.9 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from pymongo import MongoClient

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path to your CSV file in Google Drive
csv_file_path = "/content/drive/My Drive/ETL_Pipeline/output/final_cleaned_data.csv"  # Update this path

# Load the CSV file into a DataFrame
final_cleaned_data = pd.read_csv(csv_file_path)

# Display the first few rows
final_cleaned_data.head()
# Out:
#                         date      open      high       low     close  \
# 0  2023-04-28 00:00:00+00:00  33797.43  34104.56  33728.40  34098.16
# 1  2023-04-27 00:00:00+00:00  33381.66  33859.75  33374.65  33826.16
# 2  2023-04-26 00:00:00+00:00  33596.34  33645.83  33235.85  33301.87
# 3  2023-04-25 00:00:00+00:00  33828.34  33875.49  33525.39  33530.83
# 4  2023-04-24 00:00:00+00:00  33805.04  33891.15  33726.09  33875.40
#
#         volume symbol
# 0  354310000.0  YAHOO
# 1  343240000.0  YAHOO
# 2  321170000.0  YAHOO
# 3  297880000.0  YAHOO
# 4  252020000.0  YAHOO

# %%
# MongoDB connection
uri = "mongodb+srv://Waqas:Waqasali98@cluster01.9h0b0.mongodb.net/Clusters?retryWrites=true&w=majority"
client = MongoClient(uri)
db = client["Clusters"]
collection = db["5_stock_data"]

# %%
# Convert the DataFrame to a list of dictionaries
data_dict = final_cleaned_data.to_dict(orient="records")

# Insert the data into MongoDB
collection.insert_many(data_dict)

print("Data uploaded to MongoDB successfully!")
# Out:
# Data uploaded to MongoDB successfully!

# %% [markdown]
# #Data Retrieval

# %%
import pandas as pd
from pymongo import MongoClient

# MongoDB connection
uri = "mongodb+srv://Waqas:Waqasali98@cluster01.9h0b0.mongodb.net/Clusters?retryWrites=true&w=majority"
client = MongoClient(uri)
db = client["Clusters"]
collection = db["5_stock_data"]

# Retrieve the data from MongoDB
data = collection.find()

# Convert the MongoDB result to a Pandas DataFrame
df_retrieved = pd.DataFrame(list(data))

# Display the first few rows of the DataFrame
df_retrieved.head()
# Out:
#                         _id                       date      open      high  \
# 0  67f0eb931011deef593066fc  2023-04-28 00:00:00+00:00  33797.43  34104.56
# 1  67f0eb931011deef593066fd  2023-04-27 00:00:00+00:00  33381.66  33859.75
# 2  67f0eb931011deef593066fe  2023-04-26 00:00:00+00:00  33596.34  33645.83
# 3  67f0eb931011deef593066ff  2023-04-25 00:00:00+00:00  33828.34  33875.49
# 4  67f0eb931011deef59306700  2023-04-24 00:00:00+00:00  33805.04  33891.15
#
#         low     close       volume symbol
# 0  33728.40  34098.16  354310000.0  YAHOO
# 1  33374.65  33826.16  343240000.0  YAHOO
# 2  33235.85  33301.87  321170000.0  YAHOO
# 3  33525.39  33530.83  297880000.0  YAHOO
# 4  33726.09  33875.40  252020000.0  YAHOO
